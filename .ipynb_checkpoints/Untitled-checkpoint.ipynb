# %%
import os
import torch
import torchvision
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from torchvision.transforms import ToTensor, Normalize, Compose
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, random_split
import torch.nn as nn
import time

# %%
coord_all = np.load("./03_Kreuznapf/coord_all_81000001.npy")
disp_all = np.load("./03_Kreuznapf/disp_all_81000001.npy")
print(disp_all)
# Out:
# [[[ 1.49493214e+02  3.81192000e-10 -4.08049856e+01]
#   [ 0.00000000e+00  1.00726500e-10 -6.08165717e+00]
#   [ 2.03144481e+00  1.04194000e-10 -6.05481143e+00]
#   ...
#   [ 1.00620663e+02 -3.62935261e+01 -3.89447068e+01]
#   [ 8.21339667e+01 -3.95091796e+01 -3.93879573e+01]
#   [ 8.14412882e+01 -3.89192161e+01 -3.89537107e+01]]
#
#  [[ 1.36812445e+02  3.81192000e-10 -5.75168851e+01]
#   [ 0.00000000e+00  1.00726500e-10 -6.28255398e+00]
#   [ 2.02549486e+00  1.04194000e-10 -6.28259986e+00]
#   ...
#   [ 9.83061509e+01 -3.39756511e+01 -4.08831651e+01]
#   [ 7.97395785e+01 -3.57759026e+01 -4.00749360e+01]
#   [ 7.92996214e+01 -3.57687551e+01 -3.92598836e+01]]
#
#  [[ 1.37269979e+02  3.81192000e-10 -6.38233260e+01]
#   [ 0.00000000e+00  1.00726500e-10 -6.31560615e+00]
#   [ 2.04914139e+00  1.04194000e-10 -6.28445550e+00]
#   ...
#   [ 9.79404917e+01 -3.40957662e+01 -4.59608138e+01]
#   [ 7.94987113e+01 -3.58293169e+01 -4.44435375e+01]
#   [ 7.90794775e+01 -3.58265872e+01 -4.35610892e+01]]
#
#  ...
#
#  [[ 1.32215013e+02  3.81192000e-10 -6.56675354e+01]
#   [ 0.00000000e+00  1.00726500e-10 -6.27906593e+00]
#   [ 2.03579642e+00  1.04194000e-10 -6.25770726e+00]
#   ...
#   [ 9.80975110e+01 -3.40680846e+01 -4.31304089e+01]
#   [ 7.95831298e+01 -3.57715290e+01 -4.13965134e+01]
#   [ 7.91704369e+01 -3.57631138e+01 -4.05549059e+01]]
#
#  [[ 1.43999715e+02  3.81192000e-10 -5.31242506e+01]
#   [ 0.00000000e+00  1.00726500e-10 -6.15877804e+00]
#   [ 2.04814799e+00  1.04194000e-10 -6.13027824e+00]
#   ...
#   [ 9.83612618e+01 -3.39608934e+01 -4.41399878e+01]
#   [ 7.98516876e+01 -3.57201927e+01 -4.38050137e+01]
#   [ 7.93652259e+01 -3.57090311e+01 -4.29707627e+01]]
#
#  [[ 1.47932012e+02  3.81192000e-10 -4.50976433e+01]
#   [ 0.00000000e+00  1.00726500e-10 -6.31174938e+00]
#   [ 2.03724591e+00  1.04194000e-10 -6.28877863e+00]
#   ...
#   [ 9.95796539e+01 -3.49746231e+01 -4.14309594e+01]
#   [ 8.11816445e+01 -3.75436362e+01 -4.18376447e+01]
#   [ 8.05357441e+01 -3.71107281e+01 -4.12069486e+01]]]

# %%
def de_norm(tensor, mean, std):
    return tensor*std + mean

# %%
for exp in range(2):
    fig = plt.figure(figsize=(10,10))
    xi = disp_all[exp,:,0]
    yi = disp_all[exp,:,1]
    zi = disp_all[exp,:,2]
    ax = fig.add_subplot(projection='3d')
    plt.xlabel("X coordinate")
    plt.ylabel("Y coordinate")
    ax.scatter3D(xi, yi, zi, c=zi, cmap='nipy_spectral')
    ax.view_init(elev=45,azim=0)
    plt.show()

# %%
class Geom_Dataset(Dataset):
    def __init__(self): #transform=None
        super().__init__()
        
        ## here you can add the file path
        self.data_name=pd.read_csv('./03_Kreuznapf/Experiments_1_without_Error_Term.csv', sep=';', decimal=',')
        self.x = torch.tensor(self.data_name[['F_press','fs','h_BT']].values, dtype = torch.float32)
        print("size of input is ",self.x.size())

        #Output
        disp_all = np.load("./03_Kreuznapf/disp_all_81000001.npy")
        disp_all = torch.tensor(disp_all, dtype=torch.float32)
        
        self.y = torch.hstack((disp_all[:,:,0],disp_all[:,:,1],disp_all[:,:,2]))
        self.y= self.transform()
        
        print("size of output is \n",self.y.size())
        print(self.y)
        self.len = self.x.shape[0]
        
    def transform(self):
        self.mean= self.y.mean()
        self.std= 3*self.y.std()
#         print(self.mean, self.std)
        return (self.y- self.mean)/self.std
    
    def __len__(self):
        return self.len
     
    def __getitem__(self, index):

        return self.x[index],self.y[index]
    
data = Geom_Dataset()
# Out:
# size of input is  torch.Size([249, 3])
# size of output is
#  torch.Size([249, 14943])
# tensor([[ 0.9131,  0.0451,  0.0569,  ..., -0.1810, -0.1836, -0.1811],
#         [ 0.8395,  0.0451,  0.0569,  ..., -0.1923, -0.1876, -0.1828],
#         [ 0.8421,  0.0451,  0.0570,  ..., -0.2217, -0.2129, -0.2078],
#         ...,
#         [ 0.8128,  0.0451,  0.0569,  ..., -0.2053, -0.1952, -0.1904],
#         [ 0.8812,  0.0451,  0.0570,  ..., -0.2112, -0.2092, -0.2044],
#         [ 0.9040,  0.0451,  0.0569,  ..., -0.1954, -0.1978, -0.1941]])

# %%
val_size = 50
train_size = len(data) - val_size
batch_size = math.ceil(train_size)

train_ds, val_ds = random_split(data, [train_size, val_size])
print("the train size is {}, validation size is {} and batch size is {} ".format(len(train_ds), len(val_ds), batch_size))

train_loader = DataLoader(train_ds, batch_size, shuffle=True)
val_loader = DataLoader(val_ds, batch_size)
# Out:
# the train size is 199, validation size is 50 and batch size is 199

# %%
class Gen_Sneha(nn.Module):
    def __init__(self, in_size=3, h=5,outsize=14943, p=0.0):
        
        super().__init__()
        self.in_size = in_size
        self.outsize = outsize
        self.h = h
        self.L= h
        
        self.hidden=nn.ModuleList()
        self.Layers = [in_size, *[2**(2*i) for i in range(3,h+2)], outsize]
        print(self.Layers)
        
        for i,(input_size,output_size) in enumerate(zip(self.Layers, self.Layers[1:])):
            if i<self.L-1:
                self.hidden.append(nn.Linear(input_size, output_size, bias=False))
                self.hidden.append(nn.BatchNorm1d(output_size))
                self.hidden.append(nn.ReLU())
                self.hidden.append(nn.Dropout(p=p))
            else:
                self.hidden.append(nn.Linear(input_size, output_size, bias=False))
                self.hidden.append(nn.Tanh())
                
    def forward(self, activation):
        for linear_transform in self.hidden:
            activation= linear_transform(activation)
        return activation

# %%
class Dis_Sneha(nn.Module):
    def __init__(self, in_size=14943, h=5,outsize=1, p=0.33, Wgan=False):
        
        super().__init__()
        self.in_size = in_size
        self.outsize = outsize
        self.h = h
        self.L= h
       
        self.Wgan=Wgan
        self.hidden=nn.ModuleList()
        self.Layers = [in_size, *[2**(2*i) for i in range(h+1,2,-1)], outsize]
        print(self.Layers)
    
        for i,(input_size,output_size) in enumerate(zip(self.Layers, self.Layers[1:])):
            if i<self.L-1:
                self.hidden.append(nn.Linear(input_size, output_size, bias=False))
                self.hidden.append(nn.BatchNorm1d(output_size))
                self.hidden.append(nn.LeakyReLU(0.2))
                self.hidden.append(nn.Dropout(p=p))
            else:
                self.hidden.append(nn.Linear(input_size, output_size, bias=False))
                if not self.Wgan:
                    self.hidden.append(nn.Sigmoid())
                
    def forward(self, activation):
        for linear_transform in self.hidden:
            activation= linear_transform(activation)
        return activation

# %%
from torchsummary import summary

# %%
G= Gen_Sneha()
D= Dis_Sneha()
print(G)
print(D)
# G.eval()
# G(torch.tensor([[1,2,3]], dtype=torch.float32))
# Out:
# [3, 64, 256, 1024, 4096, 14943]
# [14943, 4096, 1024, 256, 64, 1]
# Gen_Sneha(
#   (hidden): ModuleList(
#     (0): Linear(in_features=3, out_features=64, bias=False)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=64, out_features=256, bias=False)
#     (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.0, inplace=False)
#     (8): Linear(in_features=256, out_features=1024, bias=False)
#     (9): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.0, inplace=False)
#     (12): Linear(in_features=1024, out_features=4096, bias=False)
#     (13): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.0, inplace=False)
#     (16): Linear(in_features=4096, out_features=14943, bias=False)
#     (17): Tanh()
#   )
# )
# Dis_Sneha(
#   (hidden): ModuleList(
#     (0): Linear(in_features=14943, out_features=4096, bias=False)
#     (1): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Dropout(p=0.33, inplace=False)
#     (4): Linear(in_features=4096, out_features=1024, bias=False)
#     (5): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.2)
#     (7): Dropout(p=0.33, inplace=False)
#     (8): Linear(in_features=1024, out_features=256, bias=False)
#     (9): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Dropout(p=0.33, inplace=False)
#     (12): Linear(in_features=256, out_features=64, bias=False)
#     (13): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.2)
#     (15): Dropout(p=0.33, inplace=False)
#     (16): Linear(in_features=64, out_features=1, bias=False)
#     (17): Sigmoid()
#   )
# )

# %%
r_size=3
epochs= 30

# %%
def getRandomVector():
    rand_vect= torch.randn(batch_size, r_size)
    return rand_vect

# %%
def plot(lossDict, ganType):
    fig = plt.figure(figsize=(10,8))


    plt.plot(lossDict['Epoch'],  lossDict['D_loss'], 'o-',label='D')
    plt.plot(lossDict['Epoch'],  lossDict['G_loss'], 'o-',label='G')

    ax = plt.gca()

    plt.ylabel('Cross-Entropy Loss')
    plt.xlabel('Epochs')
    plt.legend(fontsize=20, ncol=3) 

    plt.title('GANs Loss', pad=12)
#     plt.savefig("{}.png".format(ganType))
    plt.show()

# %%
#Training Wasserstein Gan formulation
def WStein_Gan(train_loader, epochs=30):

    G= Gen_Sneha()
    D= Dis_Sneha(Wgan=True)
    
    D_iterations= 1
    Weight_clip= 0.01
    Gan_type= 'WStein_Gan'

    G_opt= torch.optim.RMSprop(G.parameters(), lr= 2e-4)
    D_opt= torch.optim.RMSprop(D.parameters(), lr= 2e-4)
    
    lossDict= {'Epoch':[],'D_loss':[], 'G_loss':[]}
    
    for epoch in range(epochs):
        D_lossCum=0
        G_lossCum=0
        for params, coords in train_loader:
            ## Discriminator Training
            for i in range(D_iterations):
                fake_coords= G(params+getRandomVector()).detach()
                D_loss= -(D(coords).mean() - D(fake_coords).mean())
                D_lossCum+=D_loss.item()
                D_opt.zero_grad()
                D_loss.backward(retain_graph= True)
                grad_vec= torch.cat([g.grad.contiguous().view(-1) for g in D.parameters()])
                print('Dis',grad_vec.min(), grad_vec.max(), grad_vec.mean(), grad_vec.std())
                D_opt.step()
                ## Clamping weights [-0.01, 0.01]
                for weight in D.parameters():
                    weight.detach().clamp_(-Weight_clip, Weight_clip)
            #D_lossCum=D_lossCum/D_iterations
            
            ##Generator training
            fake_coords= G(params) 
            G_loss= -D(fake_coords).mean()
            G_lossCum+=G_loss.item()
            G_opt.zero_grad()
            G_loss.backward()
            grad_vec= torch.cat([g.grad.contiguous().view(-1) for g in G.parameters()])
            print('Gen',grad_vec.min(), grad_vec.max(), grad_vec.mean(), grad_vec.std())
            G_opt.step()
            
        lossDict['Epoch'].append(epoch+1)
        lossDict['D_loss'].append(D_lossCum/batch_size)
        lossDict['G_loss'].append(G_lossCum/batch_size)
        #save_fake_imgs(G, Gan_type, epoch)  
        print('Epoch:{}, D_loss:{:.4f}, G_loss:{:.4f}'.format(epoch, D_loss, G_loss))
#     torch.save(G.state_dict(), './models/G_WGan.ckpt')
#     torch.save(D.state_dict(), './models/D_WGan.ckpt')
    plot(lossDict, Gan_type)
    
    return lossDict

# %%
WStein_Gan(train_loader)
# Out:
# [3, 64, 256, 1024, 4096, 14943]
# [14943, 4096, 1024, 256, 64, 1]
# Dis tensor(-0.2375) tensor(0.0533) tensor(-2.6663e-06) tensor(0.0019)
# Gen tensor(-3.4373e-05) tensor(4.4116e-05) tensor(3.8022e-10) tensor(5.4917e-08)
# Epoch:0, D_loss:0.0359, G_loss:-0.0002
# Dis tensor(-0.0020) tensor(0.0023) tensor(-2.2527e-10) tensor(1.2165e-06)
# Gen tensor(-3.0909e-05) tensor(1.4650e-05) tensor(2.4015e-10) tensor(4.6028e-08)
# Epoch:1, D_loss:0.0000, G_loss:-0.0001
# Dis tensor(-0.0020) tensor(0.0020) tensor(1.8449e-13) tensor(1.1092e-06)
# Gen tensor(-1.2995e-05) tensor(5.5750e-05) tensor(-5.5388e-11) tensor(6.2739e-08)
# Epoch:2, D_loss:-0.0000, G_loss:-0.0001
# Dis tensor(-0.0022) tensor(0.0033) tensor(-3.0553e-10) tensor(1.1719e-06)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-6f4e1849824c> in <module>
# ----> 1 WStein_Gan(train_loader)
#
# <ipython-input-51-76eda0449fdb> in WStein_Gan(train_loader, epochs)
#      38             G_lossCum+=G_loss.item()
#      39             G_opt.zero_grad()
# ---> 40             G_loss.backward()
#      41             grad_vec= torch.cat([g.grad.contiguous().view(-1) for g in G.parameters()])
#      42             print('Gen',grad_vec.min(), grad_vec.max(), grad_vec.mean(), grad_vec.std())
#
# ~/anaconda3/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
#Training non-saturating formulation
def NonSaturating_Gan(train_loader, epochs):

    G= Gen_Sneha()
    
    D= Dis_Sneha()
    D_iterations= 1

    Gan_type= 'NonSaturating_Gan'
    
 
    G_opt= torch.optim.RMSprop(G.parameters(), lr= 0.00609)
    D_opt= torch.optim.RMSprop(D.parameters(), lr= 0.003)
    
    criterion= nn.BCELoss()
    
    lossDict= {'Epoch':[],'D_loss':[], 'G_loss':[]}
    
    for epoch in range(epochs):
        D_lossCum=0
        G_lossCum=0
        for params,coords in train_loader:
            fake_coords= G(params)
            for _ in range(D_iterations):
                ## Discriminator Training
                #D_loss= -(torch.log(D(real_imgs)).mean() + torch.log(1-D(fake_imgs)).mean())
                D_loss= criterion(D(coords), 0.9*torch.ones_like(D(coords))) + criterion(D(fake_coords.detach()), torch.zeros_like(D(fake_coords)))
                D_lossCum+=D_loss.item()
                D_opt.zero_grad()
                D_loss.backward(retain_graph= True)
                D_opt.step()
                D_opt.zero_grad()
            
            ##Generator training
            #G_loss= -torch.log(D(fake_imgs)).mean()
            G_loss= criterion(D(fake_coords), torch.ones_like(D(fake_coords)))
            G_lossCum+=G_loss.item()
            G_opt.zero_grad()
            G_loss.backward()
            G_opt.step()
        
        lossDict['Epoch'].append(epoch)
        lossDict['D_loss'].append(D_lossCum/batch_size)
        lossDict['G_loss'].append(G_lossCum/batch_size)
        #save_fake_imgs(G, Gan_type, epoch)  
        print('Epoch:{}, D_loss:{:.4f}, G_loss:{:.4f}'.format(epoch, D_loss, G_loss))
    
    torch.save(G.state_dict(), './models/G_NonSaturating.ckpt')
    torch.save(D.state_dict(), './models/D_NonSaturating.ckpt')
    plot(lossDict, Gan_type)
    return lossDict

# %%
# loss=NonSaturating_Gan(train_loader, epochs=30)

# %%
#Training non-saturating formulation
def NonSaturating_Gan2(train_loader, epochs):

    G= Gen_Sneha()
    
    D= Dis_Sneha()
    D_iterations= 2

    Gan_type= 'NonSaturating_Gan'
    
    activation={}
    def getActivation(name):
        def hook(model, input, output):
            activation[name]= output
        return hook
    h1= D.hidden[12].register_forward_hook(getActivation('features'))
            
 
    G_opt= torch.optim.Adam(G.parameters(), lr= 0.00609)
    D_opt= torch.optim.Adam(D.parameters(), lr= 0.003)
    
    criterion= nn.BCELoss()
    criterionG= nn.MSELoss()
    
    lossDict= {'Epoch':[],'D_loss':[], 'G_loss':[]}
    
    for epoch in range(epochs):
        D_lossCum=0
        G_lossCum=0
        for params,coords in train_loader:
            fake_coords= G(params)
            for _ in range(D_iterations):
                ## Discriminator Training
                #D_loss= -(torch.log(D(real_imgs)).mean() + torch.log(1-D(fake_imgs)).mean())
                D_loss= criterion(D(coords), 0.9*torch.ones_like(D(coords))) + criterion(D(fake_coords.detach()), torch.zeros_like(D(fake_coords)))
                D_lossCum+=D_loss.item()
                D_opt.zero_grad()
                D_loss.backward(retain_graph= True)
                grad_vec= torch.cat([g.grad.contiguous().view(-1) for g in D.parameters()])
                print('Dis',grad_vec.min(), grad_vec.max(), grad_vec.mean(), grad_vec.std())
                D_opt.step()
                D_opt.zero_grad()
            
            ##Generator training
            #G_loss= -torch.log(D(fake_imgs)).mean()
            
            ##########Getting Features#########
            D(coords.detach())
            real_features= activation['features']
            D(fake_coords)
            fake_features= activation['features']
            #############To Compare############
            
            G_loss= criterionG(torch.mean(real_features, 0), torch.mean(fake_features,0))
            G_lossCum+=G_loss.item()
            G_opt.zero_grad()
            G_loss.backward()
            grad_vec= torch.cat([g.grad.contiguous().view(-1) for g in G.parameters()])
            print('Gen',grad_vec.min(), grad_vec.max(), grad_vec.mean(), grad_vec.std())
            G_opt.step()
        
        lossDict['Epoch'].append(epoch)
        lossDict['D_loss'].append(D_lossCum/batch_size)
        lossDict['G_loss'].append(G_lossCum/batch_size)
        #save_fake_imgs(G, Gan_type, epoch)  
        print('Epoch:{}, D_loss:{:.4f}, G_loss:{:.4f}'.format(epoch, D_loss, G_loss))
    
    torch.save(G.state_dict(), './models/G_NonSaturating.ckpt')
    torch.save(D.state_dict(), './models/D_NonSaturating.ckpt')
    plot(lossDict, Gan_type)
    
    h1.remove()
    return lossDict

# %%
loss=NonSaturating_Gan2(train_loader, epochs=30)
# Out:
# [3, 64, 256, 1024, 4096, 14943]
# [14943, 4096, 1024, 256, 64, 1]
# Dis tensor(-0.1035) tensor(0.1320) tensor(1.1102e-06) tensor(0.0009)
# Dis tensor(-0.1056) tensor(0.1088) tensor(2.8585e-07) tensor(0.0003)
# Gen tensor(-0.0002) tensor(0.0002) tensor(4.0180e-08) tensor(1.2582e-06)
# Epoch:0, D_loss:1.4501, G_loss:0.0091
# Dis tensor(-0.0573) tensor(0.1637) tensor(7.7563e-08) tensor(0.0002)
# Dis tensor(-0.0429) tensor(0.1556) tensor(1.9238e-08) tensor(0.0002)
# Gen tensor(-0.0006) tensor(0.0004) tensor(-6.1521e-10) tensor(2.1451e-06)
# Epoch:1, D_loss:1.4520, G_loss:0.0025
# Dis tensor(-0.0229) tensor(0.1413) tensor(-2.6178e-08) tensor(0.0001)
# Dis tensor(-0.0710) tensor(0.1356) tensor(7.7719e-08) tensor(0.0001)
# Gen tensor(-0.0007) tensor(0.0007) tensor(3.9972e-09) tensor(1.7929e-06)
# Epoch:2, D_loss:1.4030, G_loss:0.0027
# Dis tensor(-0.0407) tensor(0.1667) tensor(-1.2860e-07) tensor(0.0001)
# Dis tensor(-0.0818) tensor(0.1742) tensor(1.7982e-07) tensor(9.2270e-05)
# Gen tensor(-0.0005) tensor(0.0005) tensor(1.0600e-09) tensor(1.2345e-06)
# Epoch:3, D_loss:1.3946, G_loss:0.0018
# Dis tensor(-0.1059) tensor(0.0851) tensor(3.8892e-08) tensor(8.3943e-05)
# Dis tensor(-0.0927) tensor(0.0829) tensor(8.3222e-09) tensor(7.4481e-05)
# Gen tensor(-0.0012) tensor(0.0010) tensor(7.7223e-11) tensor(1.3609e-06)
# Epoch:4, D_loss:1.3786, G_loss:0.0026
# Dis tensor(-0.0958) tensor(0.1222) tensor(-2.8674e-08) tensor(7.5816e-05)
# Dis tensor(-0.0709) tensor(0.0888) tensor(-5.8442e-08) tensor(6.3838e-05)
# Gen tensor(-0.0007) tensor(0.0008) tensor(-1.3840e-09) tensor(1.3252e-06)
# Epoch:5, D_loss:1.3629, G_loss:0.0034
# Dis tensor(-0.0770) tensor(0.0758) tensor(1.1110e-07) tensor(6.2206e-05)
# Dis tensor(-0.0795) tensor(0.0731) tensor(-3.7586e-09) tensor(5.8298e-05)
# Gen tensor(-0.0014) tensor(0.0008) tensor(-2.0306e-09) tensor(1.1116e-06)
# Epoch:6, D_loss:1.3587, G_loss:0.0019
# Dis tensor(-0.1346) tensor(0.0720) tensor(7.8278e-08) tensor(6.6240e-05)
# Dis tensor(-0.1038) tensor(0.1388) tensor(7.1982e-08) tensor(6.1429e-05)
# Gen tensor(-0.0009) tensor(0.0008) tensor(1.1233e-09) tensor(1.0357e-06)
# Epoch:7, D_loss:1.3613, G_loss:0.0026
# Dis tensor(-0.0625) tensor(0.0888) tensor(2.2553e-08) tensor(5.7002e-05)
# Dis tensor(-0.0762) tensor(0.0978) tensor(9.4176e-08) tensor(5.9668e-05)
# Gen tensor(-0.0007) tensor(0.0005) tensor(-1.6341e-09) tensor(9.0431e-07)
# Epoch:8, D_loss:1.3950, G_loss:0.0023
# Dis tensor(-0.1077) tensor(0.1005) tensor(6.2555e-08) tensor(5.8564e-05)
# Dis tensor(-0.1215) tensor(0.0810) tensor(3.8963e-08) tensor(5.6218e-05)
# Gen tensor(-0.0010) tensor(0.0006) tensor(1.6071e-09) tensor(1.0819e-06)
# Epoch:9, D_loss:1.3667, G_loss:0.0027
# Dis tensor(-0.1334) tensor(0.0701) tensor(7.8492e-08) tensor(5.8853e-05)
# Dis tensor(-0.1399) tensor(0.1031) tensor(1.0177e-07) tensor(5.8843e-05)
# Gen tensor(-0.0008) tensor(0.0010) tensor(4.0609e-09) tensor(9.8854e-07)
# Epoch:10, D_loss:1.3804, G_loss:0.0037
# Dis tensor(-0.0816) tensor(0.0780) tensor(1.2742e-07) tensor(5.1479e-05)
# Dis tensor(-0.1076) tensor(0.0686) tensor(-1.1172e-08) tensor(5.0543e-05)
# Gen tensor(-0.0027) tensor(0.0009) tensor(-1.0802e-09) tensor(1.1254e-06)
# Epoch:11, D_loss:1.3547, G_loss:0.0024
# Dis tensor(-0.0662) tensor(0.0970) tensor(4.7049e-08) tensor(5.0778e-05)
# Dis tensor(-0.1003) tensor(0.0953) tensor(-1.1773e-07) tensor(5.2816e-05)
# Gen tensor(-0.0008) tensor(0.0015) tensor(7.1089e-10) tensor(1.1523e-06)
# Epoch:12, D_loss:1.3471, G_loss:0.0038
# Dis tensor(-0.0642) tensor(0.0782) tensor(-4.4837e-08) tensor(4.9099e-05)
# Dis tensor(-0.0688) tensor(0.0762) tensor(3.3738e-08) tensor(4.6627e-05)
# Gen tensor(-0.0008) tensor(0.0010) tensor(3.2952e-09) tensor(1.1141e-06)
# Epoch:13, D_loss:1.3508, G_loss:0.0029
# Dis tensor(-0.0823) tensor(0.0785) tensor(5.3768e-08) tensor(4.7099e-05)
# Dis tensor(-0.0748) tensor(0.0472) tensor(4.6531e-08) tensor(4.3597e-05)
# Gen tensor(-0.0011) tensor(0.0007) tensor(3.8547e-09) tensor(9.9013e-07)
# Epoch:14, D_loss:1.3360, G_loss:0.0033
# Dis tensor(-0.0699) tensor(0.1269) tensor(7.1100e-08) tensor(4.8983e-05)
# Dis tensor(-0.0881) tensor(0.0558) tensor(3.9296e-09) tensor(4.5772e-05)
# Gen tensor(-0.0007) tensor(0.0009) tensor(-3.7765e-09) tensor(1.0472e-06)
# Epoch:15, D_loss:1.3208, G_loss:0.0030
# Dis tensor(-0.0906) tensor(0.1149) tensor(-5.7697e-08) tensor(4.9675e-05)
# Dis tensor(-0.0507) tensor(0.1120) tensor(-6.6078e-09) tensor(4.1037e-05)
# Gen tensor(-0.0012) tensor(0.0022) tensor(-1.0162e-09) tensor(1.2204e-06)
# Epoch:16, D_loss:1.3234, G_loss:0.0042
# Dis tensor(-0.0614) tensor(0.0939) tensor(1.4035e-08) tensor(4.3870e-05)
# Dis tensor(-0.0787) tensor(0.0597) tensor(6.0930e-08) tensor(4.3062e-05)
# Gen tensor(-0.0030) tensor(0.0013) tensor(-4.7608e-09) tensor(1.4019e-06)
# Epoch:17, D_loss:1.3037, G_loss:0.0041
# Dis tensor(-0.0807) tensor(0.0836) tensor(1.1266e-07) tensor(4.9071e-05)
# Dis tensor(-0.0798) tensor(0.0717) tensor(7.9816e-08) tensor(4.3610e-05)
# Gen tensor(-0.0015) tensor(0.0006) tensor(-5.5588e-09) tensor(9.7030e-07)
# Epoch:18, D_loss:1.3082, G_loss:0.0030
# Dis tensor(-0.0675) tensor(0.0882) tensor(9.8965e-08) tensor(4.4229e-05)
# Dis tensor(-0.1028) tensor(0.1055) tensor(1.0461e-07) tensor(5.1180e-05)
# Gen tensor(-0.0010) tensor(0.0030) tensor(-1.4591e-09) tensor(1.3913e-06)
# Epoch:19, D_loss:1.2855, G_loss:0.0040
# Dis tensor(-0.1240) tensor(0.0847) tensor(1.1391e-07) tensor(4.9531e-05)
# Dis tensor(-0.0842) tensor(0.0920) tensor(8.4605e-08) tensor(4.8493e-05)
# Gen tensor(-0.0022) tensor(0.0017) tensor(-4.5585e-09) tensor(1.7559e-06)
# Epoch:20, D_loss:1.3133, G_loss:0.0044
# Dis tensor(-0.0625) tensor(0.0890) tensor(9.0028e-08) tensor(4.8708e-05)
# Dis tensor(-0.0539) tensor(0.0938) tensor(6.6851e-08) tensor(4.6796e-05)
# Gen tensor(-0.0013) tensor(0.0015) tensor(9.4198e-10) tensor(9.7402e-07)
# Epoch:21, D_loss:1.3060, G_loss:0.0034
# Dis tensor(-0.0581) tensor(0.1168) tensor(1.0401e-09) tensor(4.9732e-05)
# Dis tensor(-0.0713) tensor(0.1027) tensor(-7.0690e-08) tensor(4.9192e-05)
# Gen tensor(-0.0013) tensor(0.0037) tensor(-9.6124e-10) tensor(1.4922e-06)
# Epoch:22, D_loss:1.2884, G_loss:0.0058
# Dis tensor(-0.0602) tensor(0.1128) tensor(-3.0903e-08) tensor(4.7334e-05)
# Dis tensor(-0.0641) tensor(0.1124) tensor(-3.3928e-08) tensor(4.7095e-05)
# Gen tensor(-0.0019) tensor(0.0023) tensor(1.0019e-09) tensor(1.5548e-06)
# Epoch:23, D_loss:1.2674, G_loss:0.0050
# Dis tensor(-0.0658) tensor(0.0675) tensor(-4.8391e-08) tensor(4.7940e-05)
# Dis tensor(-0.0805) tensor(0.0749) tensor(-2.8938e-08) tensor(5.3105e-05)
# Gen tensor(-0.0032) tensor(0.0033) tensor(1.2781e-09) tensor(2.5185e-06)
# Epoch:24, D_loss:1.2718, G_loss:0.0079
# Dis tensor(-0.1011) tensor(0.1012) tensor(-6.1164e-08) tensor(5.3682e-05)
# Dis tensor(-0.1183) tensor(0.0947) tensor(5.8242e-08) tensor(5.4223e-05)
# Gen tensor(-0.0025) tensor(0.0026) tensor(7.5808e-09) tensor(2.0996e-06)
# Epoch:25, D_loss:1.2252, G_loss:0.0066
# Dis tensor(-0.0725) tensor(0.1072) tensor(-6.2224e-08) tensor(5.0833e-05)
# Dis tensor(-0.0907) tensor(0.0862) tensor(1.0673e-07) tensor(5.3446e-05)
# Gen tensor(-0.0028) tensor(0.0025) tensor(1.1160e-09) tensor(1.9204e-06)
# Epoch:26, D_loss:1.2694, G_loss:0.0053
# Dis tensor(-0.0899) tensor(0.1007) tensor(-8.8802e-09) tensor(5.3634e-05)
# Dis tensor(-0.0563) tensor(0.1460) tensor(8.7864e-08) tensor(5.6848e-05)
# Gen tensor(-0.0017) tensor(0.0049) tensor(-2.1479e-09) tensor(2.3961e-06)
# Epoch:27, D_loss:1.2290, G_loss:0.0107
# Dis tensor(-0.0977) tensor(0.1242) tensor(8.1863e-08) tensor(6.0232e-05)
# Dis tensor(-0.1162) tensor(0.1068) tensor(3.2699e-07) tensor(5.7267e-05)
# Gen tensor(-0.0017) tensor(0.0007) tensor(-2.0463e-09) tensor(1.1055e-06)
# Epoch:28, D_loss:1.2253, G_loss:0.0046
# Dis tensor(-0.0804) tensor(0.0986) tensor(1.0061e-07) tensor(5.5033e-05)
# Dis tensor(-0.0815) tensor(0.1634) tensor(1.0505e-07) tensor(5.8131e-05)
# Gen tensor(-0.0032) tensor(0.0088) tensor(2.4835e-09) tensor(3.8733e-06)
# Epoch:29, D_loss:1.1845, G_loss:0.0126

# %%
def visualise(exp, yhat):
    fig = plt.figure(figsize=(10,10))
    xi = yhat[exp,0:4981]
    yi = yhat[exp,4981:2*4981]
    zi = yhat[exp,2*4981:3*4981]
    ax = fig.add_subplot(projection='3d')
    plt.xlabel("X coordinate")
    plt.ylabel("Y coordinate")
    ax.scatter3D(xi, yi, zi, c=zi, cmap='nipy_spectral')
    ax.view_init(elev=45,azim=0)
    plt.show()

# %%
G= Gen_Sneha()
# G.load_state_dict(torch.load('./models/G_NonSaturating.ckpt'))
D= Dis_Sneha()
# D.load_state_dict(torch.load('./models/D_NonSaturating.ckpt'))
# G.eval()
x,y= next(iter(train_loader))
yhat= G(x)
print(yhat)
print(y)
yhat= de_norm(yhat.data, data.mean, data.std)
visualise(7,yhat)
# Out:
# [3, 64, 256, 1024, 4096, 14943]
# [14943, 4096, 1024, 256, 64, 1]
# tensor([[-0.0198, -0.1582,  0.1188,  ...,  0.0209,  0.0715, -0.0968],
#         [-0.0624,  0.0700, -0.1097,  ...,  0.1382,  0.0183,  0.1267],
#         [-0.1787,  0.0488, -0.0300,  ...,  0.2254, -0.0518,  0.1754],
#         ...,
#         [-0.2010,  0.2240,  0.0902,  ...,  0.0056,  0.0667, -0.0564],
#         [-0.0901, -0.0074,  0.1678,  ...,  0.1416,  0.0247,  0.0354],
#         [-0.1282,  0.0684, -0.1136,  ...,  0.0967, -0.1194,  0.0794]],
#        grad_fn=<TanhBackward>)
# tensor([[ 0.7431,  0.0451,  0.0569,  ..., -0.1858, -0.1801, -0.1755],
#         [ 0.9382,  0.0451,  0.0574,  ..., -0.2339, -0.2336, -0.2328],
#         [ 0.8033,  0.0451,  0.0569,  ..., -0.1961, -0.1875, -0.1827],
#         ...,
#         [ 0.8430,  0.0451,  0.0568,  ..., -0.1826, -0.1807, -0.1762],
#         [ 0.9062,  0.0451,  0.0569,  ..., -0.1862, -0.1885, -0.1853],
#         [ 0.8827,  0.0451,  0.0571,  ..., -0.2217, -0.2180, -0.2130]])

# %%
from hessian_eigenthings import compute_hessian_eigenthings

# %%
from hessian_eigenthings.hvp_operator import HVPOperator

# %%
class SubHVPOperator(HVPOperator):
    def __init__(
        self,
        model,
        model2,
        dataloader,
        criterion,
        use_gpu=False,
        fp16=False,
        full_dataset=False,
        max_samples=256,):
        
        self.model2= model2
        super(SubHVPOperator, self).__init__(model,dataloader,criterion,use_gpu=False,fp16=False,full_dataset=False,max_samples=256)
        
    def _prepare_grad(self):
        """
        Compute gradient w.r.t loss over all parameters and vectorize
        """
        try:
            params, coords= next(self.dataloader_iter)
        except StopIteration:
            self.dataloader_iter= iter(self.dataloader)
            params, coords= next(self.dataloader_iter)
            
        if self.use_gpu:
            input = input.cuda()
            target = target.cuda()
        
        fake_coords= self.model2(params)
        loss= criterion(self.model(coords), 0.9*torch.ones_like(self.model(coords))) + criterion(self.model(fake_coords), torch.zeros_like(self.model(fake_coords)))

        grad_dict = torch.autograd.grad(
            loss, self.model.parameters(), create_graph=True
        )
        
        grad_vec = torch.cat([g.contiguous().view(-1) for g in grad_dict])
        
        grad_vec = utils.maybe_fp16(grad_vec, self.fp16)

        self.grad_vec = grad_vec
        return self.grad_vec

# %%
from hessian_eigenthings.lanczos import *
criterion= nn.BCELoss()

operator = SubHVPOperator(
        D,
        G,
        train_loader,
        criterion,
        use_gpu=False,
        full_dataset=False,
    )
fp16=False
use_gpu=False
size=operator.size
shape = (size, size)
num_eigenthings=10
eigenvals, eigenvecs = None, None

# %%
grad_grad=operator.apply(torch.ones_like(operator._prepare_grad()))

# %%
grad= operator._prepare_grad()

grad_grad=torch.zeros((size,size), dtype= torch.float16)
for i in range(size):
    
    grad2=torch.autograd.grad(grad[i], D.parameters(), grad_outputs=None, create_graph=True)

    grad_grad[i]= torch.cat([g.contiguous().view(-1) for g in grad2])

# %%
print(grad)
print(grad_grad)

# %%
def _scipy_apply(x):
    x = torch.from_numpy(x)
    x = utils.maybe_fp16(x, fp16)
    if use_gpu:
        x = x.cuda()
    out = operator.apply(x)
    out = utils.maybe_fp16(out, fp16)
    out = out.cpu().numpy()
    return out

scipy_op = ScipyLinearOperator(shape, _scipy_apply)
num_lanczos_vectors = min(2 * num_eigenthings, size - 1)
tol=1e-6
eigenvals, eigenvecs = eigsh(
        A=scipy_op,
        k=num_eigenthings,
        which='LM',

        tol=tol,
        ncv=num_lanczos_vectors,
        return_eigenvectors=True,
    )

# %%
params, coords= next(iter((train_loader)))
        
criterion= nn.BCELoss()

def loss(parameters):
    
    D.load_state_dict(parameters)
    fake_coords= G(params)
    return criterion(D(coords), 0.9*torch.ones_like(D(coords))) + criterion(D(fake_coords), torch.zeros_like(D(fake_coords)))

H= torch.autograd.functional.hessian(loss, D.parameters(),strict= True)

# %%
print(H)

# %%
class Residual_Base(nn.Module):
    def __init__(self, in_size, out_size, activation):
        super().__init__()
        self.in_size, self.out_size, self.activation = in_size, out_size, activation
        self.block= nn.Identity()

    def forward(self, val):
        val= self.block(val)+self.shortcut(val)
        return self.activation(val)
    
    @property
    def shortcut(self):
        return nn.Sequential(nn.Linear(self.in_size, self.out_size),
                             nn.BatchNorm1d(self.out_size))

# %%
class Residual_Block(Residual_Base):
    def __init__(self, block_sizes, activation, p):
        super().__init__(block_sizes[0], block_sizes[-1], activation[-1])
        
        self.block_sizes, self.activation, self.p =block_sizes, activation, p
        self.layer_sizes= list(zip(block_sizes, block_sizes[1:]))
        self.L= len(self.layer_sizes)
        self.hidden=[]
        self.hidden= self.get_block_layers()
        self.block= nn.Sequential(*self.hidden)

        
    def get_block_layers(self):

        for i,(input_size,output_size) in enumerate(self.layer_sizes):
            if i<self.L-1:
                self.hidden.append(nn.Linear(input_size, output_size, bias=False))
                self.hidden.append(nn.BatchNorm1d(output_size))
                self.hidden.append(self.activation[i])
                self.hidden.append(nn.Dropout(p=self.p))
            else:
                self.hidden.append(nn.Linear(input_size, output_size, bias=False))
                self.hidden.append(nn.BatchNorm1d(output_size))
        return self.hidden

# %%
a= Residual_Block([2,4,10,15],[nn.ReLU(), nn.Sigmoid()], 0.5)
print(list(a.layer_sizes))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-6d27d1b08561> in <module>
# ----> 1 a= Residual_Block([2,4,10,15],[nn.ReLU(), nn.Sigmoid()], 0.5)
#       2 print(list(a.layer_sizes))
#
# <ipython-input-137-39dc4aa50621> in __init__(self, block_sizes, activation, p)
#       3         super().__init__(block_sizes[0], block_sizes[-1], activation[-1])
#       4
# ----> 5         self.block_sizes, self.activation, self.p =block_sizes, activation, p
#       6         self.layer_sizes= list(zip(block_sizes, block_sizes[1:]))
#       7         self.L= len(self.layer_sizes)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in __setattr__(self, name, value)
#     811             elif modules is not None and name in modules:
#     812                 if value is not None:
# --> 813                     raise TypeError("cannot assign '{}' as child module '{}' "
#     814                                     "(torch.nn.Module or None expected)"
#     815                                     .format(torch.typename(value), name))
#
# TypeError: cannot assign 'list' as child module 'activation' (torch.nn.Module or None expected)

# %%
z=[2,4,10,15]
list(zip(z,z[1:]))
# Out:
# [(2, 4), (4, 10), (10, 15)]

# %%
from torchsummary import summary

b= summary(a,[(1,2)],2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-121-a21b4bda797e> in <module>
#       1 from torchsummary import summary
#       2
# ----> 3 b= summary(a,[(1,2)],2)
#
# ~/anaconda3/lib/python3.8/site-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-59-04478b9858b3> in forward(self, val)
#       6
#       7     def forward(self, val):
# ----> 8         val= self.shortcut(val)
#       9         return self.activation(val)
#      10
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     129         used for normalization (i.e. in eval mode when buffers are not None).
#     130         """
# --> 131         return F.batch_norm(
#     132             input,
#     133             # If buffers are not to be tracked, ensure that they won't be updated
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2054         _verify_batch_size(input.size())
#    2055
# -> 2056     return torch.batch_norm(
#    2057         input, weight, bias, running_mean, running_var,
#    2058         training, momentum, eps, torch.backends.cudnn.enabled
#
# RuntimeError: running_mean should contain 1 elements not 15

# %%
torch.randn(2,1)
# Out:
# tensor([[-0.7490],
#         [-0.4002]])
